# %%
###### HI HELLO
import subprocess # these 2 lines below load OS functionality
import sys
import json
import warnings
import time # timing functions (for computation time)

import numpy as np # fast array library
import pandas as pd # data frames library
from pandas_ods_reader import read_ods #read ods tables

import scipy.constants as ct # import mathematical constants
import scipy.optimize as optimize # optimazation library (not used)
from scipy import signal # noise filtering functions
from scipy import stats # statistics, for binning and fields calculation

from IPython.display import display, HTML # screen on display in HTML library 

import matplotlib 
import matplotlib.pyplot as plt # plot library
import matplotlib.gridspec as gridspec

import ipywidgets as widgets # import widgets

# print progress function
# more elegant (python 3 alternative): print('\rhello', end='',flush=True)
def printp(string):
    sys.stdout.write('\r'+ str(string))
    sys.stdout.flush()
    
# Text format for figures configuration (lines below)
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica'], 'size': 14})
#rc('font',**{'family':'serif','serif':['Times']})
#rc('text', usetex=True)

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'gtk4', 'wx', 'qt4', 'qt5', 'qt6', 'qt', 'osx', 'nbagg', 'webagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# %matplotlib widget

# %%
A1 = pd.read_pickle('/home/fvega/Datos/blades/packing_fraction_045/9bd37c11859b49f916d355e03d62a6fc.pkl.xz', compression='xz')['aut'].values
A2 = pd.read_pickle('/home/fvega/Datos/blades/packing_fraction_045/712d5be2fce52eade6c5564a1f80368f.pkl.xz', compression='xz')['aut'].values
t = pd.read_pickle('/home/fvega/Datos/blades/packing_fraction_045/712d5be2fce52eade6c5564a1f80368f.pkl.xz').index.values/900

# %%
A1 = pd.read_pickle('/home/fvega/Datos/blades/vel/9bd37c11859b49f916d355e03d62a6fc_aut.pkl.xz', compression='xz')['aut'].values
A2 = pd.read_pickle('/home/fvega/Datos/blades/vel/712d5be2fce52eade6c5564a1f80368f_aut.pkl.xz', compression='xz')['aut'].values
t = pd.read_pickle('/home/fvega/Datos/blades/vel/712d5be2fce52eade6c5564a1f80368f_aut.pkl.xz').index.values/900

# %%
plt.figure(1)
plt.xlim(0,1)
#plt.ylim(0.2,1)
plt.xlabel(r'$\tau$')
plt.ylabel(r'$A$')
plt.plot(t,A1, '.' , c='b')
plt.plot(t,A2, '.' , c='r')
plt.legend(['T = 0.46', 'T = 2.65'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close(1)
